# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read the dataset to python environment

# %%
data1=pd.read_csv(r'C:\Users\VARSHA P M\Desktop\DSA\iris.csv')

# %%
data1
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    NaN  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  NaN  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Do the necessary pre-processing steps

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              143 non-null    float64
#  1   SW              144 non-null    float64
#  2   PL              144 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data1.describe()
# Out:
#                SL          SW          PL          PW
# count  143.000000  144.000000  144.000000  150.000000
# mean     5.855944    3.049306    3.756250    1.198667
# std      0.828168    0.430644    1.761306    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data1.isna().sum()
# Out:
# SL                7
# SW                6
# PL                6
# PW                0
# Classification    0
# dtype: int64

# %%
data1.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
data1.fillna(0)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    0.0  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  0.0  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data1.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  NaN  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
mean_imputed=data1.fillna(data1.mean())
mean_imputed.describe()
# Out:
# C:\Users\VARSHA P M\AppData\Local\Temp\ipykernel_16120\1533558240.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_imputed=data1.fillna(data1.mean())
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.855944    3.049306    3.756250    1.198667
# std      0.808480    0.421884    1.725479    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.200000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.200000    1.300000
# 75%      6.400000    3.275000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              143 non-null    float64
#  1   SW              144 non-null    float64
#  2   PL              144 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data1.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  NaN  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data1['SL']=data1['SL'].fillna(data1['SL'].mean())
data1.head(20)
# Out:
#           SL   SW   PL   PW Classification
# 0   5.100000  3.5  1.4  0.2    Iris-setosa
# 1   4.900000  3.0  1.4  0.2    Iris-setosa
# 2   5.855944  3.2  1.3  0.2    Iris-setosa
# 3   4.600000  3.1  1.5  0.2    Iris-setosa
# 4   5.000000  3.6  1.4  0.2    Iris-setosa
# 5   5.400000  3.9  1.7  0.4    Iris-setosa
# 6   4.600000  3.4  1.4  0.3    Iris-setosa
# 7   5.000000  3.4  1.5  0.2    Iris-setosa
# 8   4.400000  2.9  1.4  0.2    Iris-setosa
# 9   4.900000  3.1  1.5  0.1    Iris-setosa
# 10  5.400000  NaN  1.5  0.2    Iris-setosa
# 11  4.800000  3.4  1.6  0.2    Iris-setosa
# 12  4.800000  3.0  1.4  0.1    Iris-setosa
# 13  4.300000  3.0  1.1  0.1    Iris-setosa
# 14  5.800000  4.0  1.2  0.2    Iris-setosa
# 15  5.700000  4.4  1.5  0.4    Iris-setosa
# 16  5.400000  3.9  1.3  0.4    Iris-setosa
# 17  5.100000  3.5  1.4  0.3    Iris-setosa
# 18  5.700000  3.8  1.7  0.3    Iris-setosa
# 19  5.100000  3.8  1.5  0.3    Iris-setosa

# %%
data1['PW']=data1['PW'].fillna(data1['PW'].mean())
data1.head(20)
# Out:
#           SL   SW   PL   PW Classification
# 0   5.100000  3.5  1.4  0.2    Iris-setosa
# 1   4.900000  3.0  1.4  0.2    Iris-setosa
# 2   5.855944  3.2  1.3  0.2    Iris-setosa
# 3   4.600000  3.1  1.5  0.2    Iris-setosa
# 4   5.000000  3.6  1.4  0.2    Iris-setosa
# 5   5.400000  3.9  1.7  0.4    Iris-setosa
# 6   4.600000  3.4  1.4  0.3    Iris-setosa
# 7   5.000000  3.4  1.5  0.2    Iris-setosa
# 8   4.400000  2.9  1.4  0.2    Iris-setosa
# 9   4.900000  3.1  1.5  0.1    Iris-setosa
# 18  5.700000  3.800000  1.7  0.3    Iris-setosa
# ...

# %%
data1['PL']=data1['PL'].fillna(data1['PL'].mean())
data1.head(20)
# Out:
#           SL        SW   PL   PW Classification
# 0   5.100000  3.500000  1.4  0.2    Iris-setosa
# 1   4.900000  3.000000  1.4  0.2    Iris-setosa
# 2   5.855944  3.200000  1.3  0.2    Iris-setosa
# 3   4.600000  3.100000  1.5  0.2    Iris-setosa
# 4   5.000000  3.600000  1.4  0.2    Iris-setosa
# 5   5.400000  3.900000  1.7  0.4    Iris-setosa
# 6   4.600000  3.400000  1.4  0.3    Iris-setosa
# 7   5.000000  3.400000  1.5  0.2    Iris-setosa
# 8   4.400000  2.900000  1.4  0.2    Iris-setosa
# 9   4.900000  3.100000  1.5  0.1    Iris-setosa
# 10  5.400000  3.049306  1.5  0.2    Iris-setosa
# 11  4.800000  3.400000  1.6  0.2    Iris-setosa
# 12  4.800000  3.000000  1.4  0.1    Iris-setosa
# 13  4.300000  3.000000  1.1  0.1    Iris-setosa
# 14  5.800000  4.000000  1.2  0.2    Iris-setosa
# 15  5.700000  4.400000  1.5  0.4    Iris-setosa
# 16  5.400000  3.900000  1.3  0.4    Iris-setosa
# 17  5.100000  3.500000  1.4  0.3    Iris-setosa
# 18  5.700000  3.800000  1.7  0.3    Iris-setosa
# ...

# %%
X=data1.iloc[:,:-1].values
y=data1['Classification']

# %% [markdown]
# KNN algorithm
#
# #Split the dataset into training and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
svc_classifier=SVC()
svc_classifier.fit(X_train,y_train)
# Out:
# SVC()

# %%
knn_classifier=KNeighborsClassifier()
knn_classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
svc_predictions=svc_classifier.predict(X_test)
knn_predictions=knn_classifier.predict(X_test)

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import accuracy_score

# %%
svc_accuracy = accuracy_score(y_test,svc_predictions)
knn_accuracy = accuracy_score(y_test,knn_predictions)

# %%
print("Support vector Classifier Accuracy:",svc_accuracy)
print("K-Nearest Neighbors Classifier Accuracy:",knn_accuracy)
# Out:
# Support vector Classifier Accuracy: 1.0
# K-Nearest Neighbors Classifier Accuracy: 0.9666666666666667

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print(confusion_matrix(svc_predictions,y_test))
print(classification_report(knn_predictions, y_test))
# Out:
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.89      1.00      0.94         8
#  Iris-virginica       1.00      0.92      0.96        12
#
#        accuracy                           0.97        30
#       macro avg       0.96      0.97      0.97        30
#    weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# SVM Algorithm

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
from sklearn.metrics._plot.confusion_matrix import ConfusionMatrixDisplay
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
result=confusion_matrix(y_test,y_pred)
result
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 11]], dtype=int64)

# %%
labels=['Iris-setosa','Iris-versicolor','Iris-virginica']
cmd=ConfusionMatrixDisplay(result,display_labels=labels)
cmd.plot()

# %% [markdown]
# Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion="entropy",max_depth=3)
clf=clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import accuracy_score
print("Accuracy:",metrics.accuracy_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print("Accuracy:",metrics.accuracy_score(y_test,y_pred))
#
# NameError: name 'metrics' is not defined

# %% [markdown]
# Random Forest

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((100, 4), (50, 4))

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(random_state=0)
rfc.fit(X_train,y_train)
y_pred =rfc.predict(X_test)

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import accuracy_score
print('Model accuracy score with 10 decision-trees :{0:0.4f}'.format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with 10 decision-trees :0.9800

# %% [markdown]
# Random Forest Algorithm is most suitable for iris dataset for classification since accuarcy score obtained from here is 0.98 which is higher than others.
