# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read the dataset

# %%
data1=pd.read_csv(r'C:\Users\VARSHA P M\Desktop\DSA\car_age_price.csv')

# %%
data1
# Out:
#      Year   Price
# 0    2018  465000
# 1    2019  755000
# 2    2019  700000
# 3    2018  465000
# 4    2018  465000
# ..    ...     ...
# 107  2016  375000
# 108  2014  300000
# 109  2015  425000
# 110  2016  420000
# 111  2015  425000
#
# [112 rows x 2 columns]

# %%
data1.shape
# Out:
# (112, 2)

# %% [markdown]
# Data Preprocessing

# %%
data1.isna().sum()
# Out:
# Year     0
# Price    0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    112 non-null    int64
#  1   Price   112 non-null    int64
# dtypes: int64(2)
# memory usage: 1.9 KB

# %%
data1.describe()
# Out:
#               Year          Price
# count   112.000000     112.000000
# mean   2016.669643  483866.044643
# std       1.629616   91217.450533
# min    2013.000000  300000.000000
# 25%    2015.000000  423750.000000
# 50%    2017.000000  500000.000000
# 75%    2017.000000  550000.000000
# max    2020.000000  755000.000000

# %%
data1.head()
# Out:
#    Year   Price
# 0  2018  465000
# 1  2019  755000
# 2  2019  700000
# 3  2018  465000
# 4  2018  465000

# %% [markdown]
# Data Visualizations

# %%
sns.countplot(x='Price',data=data1)
# Out:
# <Axes: xlabel='Price', ylabel='count'>

# %%
sns.scatterplot(x='Year',y='Price',data=data1)
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
sns.scatterplot(x='Year',y='Price',hue='Price',data=data1,palette='viridis')
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
sns.histplot(data1['Price'],bins=30,kde=False,color='skyblue')
plt.xlabel('Year')
plt.ylabel('Price')
plt.show()

# %%
sns.jointplot(x='Year',y='Price',data=data1,kind='scatter',palette='pastel')
plt.show()

# %%
sns.boxplot(x=data1.Year, y=data1.Price, palette=("PuBuGn"))
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data1.corr(),annot=True)
plt.show()

# %% [markdown]
# Price and year are positively coorelated.

# %% [markdown]
# Create Training and Testing Split

# %%
from sklearn.model_selection import train_test_split 
 
X = data1.drop('Price',axis=1) 
Y = data1.Price 
X_train, X_test, y_train, y_test = train_test_split( 
	X, Y, train_size=0.7, test_size=0.3, random_state=100)

# %%
from sklearn import linear_model 
from sklearn.metrics import r2_score 
 
lm = linear_model.LinearRegression() 
lm.fit(X_train, y_train) 
y_pred = lm.predict(X_test) 
print(r2_score(y_true=y_test, y_pred=y_pred))
# Out:
# 0.6116755793783171

# %% [markdown]
# Linear Regression

# %%
lm = linear_model.LinearRegression() 
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model Evaluation

# %%
trainig_data_prediction=lm.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
from sklearn import metrics

# %%
y_pred = lm.predict(X_test) 
print(r2_score(y_true=y_test, y_pred=y_pred))
# Out:
# 0.6116755793783171

# %%
plt.scatter(y_train,trainig_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.show()

# %%
testing_data_prediction=lm.predict(X_test)

# %%
y_pred = lm.predict(X_train) 
print(r2_score(y_true=y_train, y_pred=y_pred))
# Out:
# 0.589965794676309

# %%
plt.scatter(y_test,testing_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.show()

# %% [markdown]
# Lasso Regression

# %%
lm = linear_model.Lasso() 
lm.fit(X_train, y_train)
# Out:
# Lasso()

# %%
trainig_data_prediction=lm.predict(X_train)

# %%
y_pred = lm.predict(X_test) 
print(r2_score(y_true=y_test, y_pred=y_pred))
# Out:
# 0.6116734145240481

# %%
plt.scatter(y_train,trainig_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.show()

# %%
testing_data_prediction=lm.predict(X_test)

# %%
y_pred = lm.predict(X_train) 
print(r2_score(y_true=y_train, y_pred=y_pred))
# Out:
# 0.5899657946312198

# %%
plt.scatter(y_test,testing_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.show()

# %% [markdown]
# Linear Regression is well performed
