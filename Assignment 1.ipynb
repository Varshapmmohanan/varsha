# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %% [markdown]
# 1.Read the dataset to python environment

# %%
dataframe = pd.read_csv(r"C:\Users\VARSHA P M\Desktop\DSA\ML_Datasets\Iris.csv")

# %%
dataframe
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# 2.Display the columns in the dataset

# %%
dataframe.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# 3.Calculate the mean of each column of the dataset

# %%
dataframe.mean(axis='index')
# Out:
# C:\Users\VARSHA P M\AppData\Local\Temp\ipykernel_2004\3208164060.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataframe.mean(axis='index')
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
dataframe.mean()
# Out:
# C:\Users\VARSHA P M\AppData\Local\Temp\ipykernel_2004\3245295385.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataframe.mean()
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %% [markdown]
# 4.Check for the null values present in the dataset

# %%
print(dataframe.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# 5. Data visualization using Scatter Plot

# %%
x = dataframe.SepalLengthCm
y = dataframe.SepalWidthCm
plt.scatter(x,y)
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
plt.title('Scatter Plot of SepalLengthCm Vs SepalWidthCm ')
plt.show()

# %% [markdown]
# 5.(ii)Data visualization using Histogram

# %%
plt.hist(dataframe['SepalLengthCm'],bins = 30, edgecolor = 'r', color = 'y')
plt.xlabel('SepalLengthCm')
plt.ylabel('Frequency')
plt.title('Histogram of SepalLengthCm')
plt.show()

# %% [markdown]
# 5.(iii)Data visualization using Distplot

# %%
sns.distplot(dataframe.SepalLengthCm,bins=30,color='r')
# Out:
# C:\Users\VARSHA P M\AppData\Local\Temp\ipykernel_2004\3285375237.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe.SepalLengthCm,bins=30,color='r')
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %% [markdown]
# 5.(iv)Data visualization using KDEPlot

# %%
sns.kdeplot(dataframe.SepalLengthCm,color='g')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>
